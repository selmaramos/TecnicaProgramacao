# %% [markdown]
# <a href="https://colab.research.google.com/github/selmaramos/Teste/blob/main/Eng_Soft_6Nov_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operadores

# %%
2**3
# Out:
# 8

# %%
23//7
# Out:
# 3

# %%
23%7
# Out:
# 2

# %%
5+5*5/5
# Out:
# 10.0

# %%
1+2*3
# Out:
# 7

# %%
(4+2)/2
# Out:
# 3.0

# %%
4**(4/2)+7
# Out:
# 23.0

# %%
(5-1)*((7+1)/(3-1))
# Out:
# 16.0

# %%
'Hello', 'world!'
# Out:
# ('Hello', 'world!')

# %%
'Alice' + 'Bob'
# Out:
# 'AliceBob'

# %%
'Alice' + '42'
# Out:
# 'Alice42'

# %%
'Alice' * 5
# Out:
# 'AliceAliceAliceAliceAlice'

# %%
'Alice' * 5
# Out:
# 'AliceAliceAliceAliceAlice'

# %%
#Tarefa 1
#Faça um programa que leia dois números
#inteiros e exiba a soma deles.


a=int(input("Informe o número: "))
b=int(input("Informe o número: "))
print("O resultado é:", a+b)
# Out:
# Informe o número: 5
# Informe o número: 5
# O resultado é: 10

# %%
#Tarefa 2
#Faça um programa que leia a nota que um
#aluno tirou em P1(Prova 1) e P2(Prova 2).

PI=float(input("Informe a nota da prova 1: "))
P2=float(input("Informe a nota da prova 2: "))
print("A média é:", (PI+P2)/2)
# Out:
# Informe a nota da prova 1: 9
# Informe a nota da prova 2: 8
# A média é: 8.5

# %%
#Tarefa 3
#Leia um nome armazenado em uma variável e imprima:
#Olá, nome_pessoa!
#(nome_pessoa é a variável)

nome=input("Informe o nome: ")
print(f"Olá, {nome}!")
# Out:
# Informe o nome: Selma
# Olá, Selma!

# %%
#Tarefa 4
#Solicite que o usuário digite seu nome.
#Solicite que o usuários digite seu ano de nascimento (formato AAAA).
#Exiba na tela:
#nome_usuario nasceu em ano_nascimento!
#(nome_usuario e ano_nascimento são as variáveis)

nome=input("Informe o nome: ")
ano=int(input("Informe o ano de nascimento: "))
# Out:
# Informe o nome: Selma
# Informe o ano de nascimento: 1998

# %%
#Tarefa 5
#Solicite que o usuário digite seu nome e sua idade.
#Imprima “Olá, nome! Você tem idade anos?”
#Imprima o ano de nascimento da pessoa (ignore meses e dias)
#Imprima o nome da pessoa idade vezes (João tem 18, imprime JoãoJoão...)

input("Informe o nome: ")
input("Informe a idade: ")
# Out:
# Informe o nome: Selma
# Informe a idade: 26
# '26'

# %%
#Tarefa 6
#Solicite ao usuário que digite três notas depois calcule e exiba a média.

nota1 = float(input("Informe a nota 1: "))
nota2 = float(input("Informe a nota 2: "))
nota3 = float(input("Informe a nota 3: "))
print("A média é:", (nota1+nota2+nota3)/3)
# Out:
# Informe a nota 1: 7
# Informe a nota 2: 5
# Informe a nota 3: 9
# A média é: 7.0

# %%
#Tarefa 7
#Solicite ao usuário três notas e seus respectivos pesos, depois calcule e exiba a
#média ponderada.
input("Informe a nota 1: ")
input("Informe o peso da nota 1: ")
input("Informe a nota 2: ")
input("Informe o peso da nota 2: ")
input("Informe a nota 3: ")
input("Informe o peso da nota 3: ")
# Out:
# Informe a nota 1: 6
# Informe o peso da nota 1: 8
# Informe a nota 2: 7
# Informe o peso da nota 2: 5
# Informe a nota 3: 9
# Informe o peso da nota 3: 9
# '9'

# %%
#Tarefa 8
#Peça ao usuário um número e exiba a soma de seus dígitos.

# %%
#Tarefa 9
